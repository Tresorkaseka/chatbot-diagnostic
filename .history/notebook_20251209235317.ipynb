# %% [markdown]
# # Notebook
#
# This is a simple Jupyter notebook created for demonstration purposes.

# %%
# You can add your code here
print("Hello, World!")

# %% [markdown]
# ## Section 1
#
# Add your content here.

# %%
# Example calculation
x = 5
y = 3
result = x + y
print(f"{x} + {y} = {result}")
